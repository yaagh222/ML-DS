# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe2.pkl','rb'))

# %%
test_input = np.array([42.87, 340350, 4000]).reshape(1,3)

# %%
pipe.predict(test_input)
# Out:
# D:\AnacondaNEW\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([998967.057974])

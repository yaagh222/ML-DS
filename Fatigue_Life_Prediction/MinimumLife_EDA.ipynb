# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\yaagh aiyappa\OneDrive\ドキュメント\csv_files\MinimumLife_Data.csv",
                index_col='PartNo')

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#           Dia2  Moment  Force    LifeMinimum
# PartNo
# DP 0    30.000  400000   8000   33177.988210
# DP 1    20.125  335750   6355    2312.609429
# DP 2    20.375   92750   4825  152895.636500
# DP 3    20.625  205250   8875    7870.191146
# DP 4    20.875  362750   2665    2887.874963

# %%
sns.scatterplot(data=df, x='Dia2',y= "Moment", hue="LifeMinimum");

# %%
sns.scatterplot(data=df, x='Dia2',y= "Force", hue="LifeMinimum");

# %%
sns.scatterplot(data=df, x='Force',y= "Moment", hue="LifeMinimum") # No acceptable relations
# Out:
# <Axes: xlabel='Force', ylabel='Moment'>

# %%
sns.lineplot(df,x='Dia2',y='Moment', hue='LifeMinimum')
# Out:
# <Axes: xlabel='Dia2', ylabel='Moment'>

# %%
sns.lineplot(df,x='Dia2',y='Force', hue='LifeMinimum')
# Out:
# <Axes: xlabel='Dia2', ylabel='Force'>

# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# C:\Users\yaagh aiyappa\AppData\Local\Temp\ipykernel_20020\2829373970.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\Users\yaagh aiyappa\OneDrive\ドキュメント\csv_files\MinimumLife_Data.csv")

# %%
df.sample(5)
# Out:
#     Unnamed: 0 PartNo    Dia2  Moment  Force    LifeMinimum
# 34          34  DP 35  28.625  259250   9145    62939.69333
# 26          26  DP 26  26.375  245750   4195    70615.14453
# 50          50  DP 51  32.625   97250   3745  1000000.00000
# 88          88  DP 89  42.125  137750   7435  1000000.00000
# 78          78  DP 79  39.625  394250   8245   733815.28630

# %%
profile = ProfileReport(df, title='Minimum under Fatigue Loading Report',explorative=True)
profile.to_file("FatigueLoading_Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

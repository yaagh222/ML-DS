# %%
import json
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import json
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import http.client

conn = http.client.HTTPSConnection("free-api-live-football-data.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "6c56a19407msh30b750159c8d003p16b8e9jsn577ef409f4aa",
    'x-rapidapi-host': "free-api-live-football-data.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/football-players-search?search=m", headers=headers)

res = conn.getresponse()
data = res.read()

d = data.decode("utf-8")
a = json.loads(d)
a
# Out:
# {'status': 'success',
#  'response': {'suggestions': [{'type': 'player',
#     'id': '701154',
#     'score': 301297,
#     'name': 'Kylian Mbappé',
#     'isCoach': False,
#     'teamId': 8633,
#     'teamName': 'Real Madrid'},
#    {'type': 'player',
#     'id': '292462',
#     'score': 301159,
#     'name': 'Mohamed Salah',
#     'isCoach': False,
#     'teamId': 8650,
#     'teamName': 'Liverpool'},
#    {'type': 'player',
#     'id': '30981',
#     'score': 301149,
#     'name': 'Lionel Messi',
#     'isCoach': False,
#     'teamId': 960720,
#     'teamName': 'Inter Miami CF'},
#    {'type': 'player',
#     'id': '923312',
#     'score': 301098,
#     'name': 'Bryan Mbeumo',
#     'isCoach': False,
#     'teamId': 10260,
#     'teamName': 'Manchester United'},
#    {'type': 'player',
#     'id': '831489',
#     'score': 301096,
#     'name': 'Alexis Mac Allister',
#     'isCoach': False,
#     'teamId': 8650,
#     'teamName': 'Liverpool'},
#    {'type': 'player',
# ...

# %%
df = pd.DataFrame(a['response']['suggestions'])
df.head()
# Out:
#      type      id   score                 name  isCoach    teamId  \
# 0  player  701154  301297        Kylian Mbappé    False    8633.0
# 1  player  292462  301159        Mohamed Salah    False    8650.0
# 2  player   30981  301149         Lionel Messi    False  960720.0
# 3  player  923312  301098         Bryan Mbeumo    False   10260.0
# 4  player  831489  301096  Alexis Mac Allister    False    8650.0
#
#             teamName
# 0        Real Madrid
# 1          Liverpool
# 2     Inter Miami CF
# 3  Manchester United
# 4          Liverpool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      50 non-null     object
#  1   id        50 non-null     object
#  2   score     50 non-null     int64
#  3   name      50 non-null     object
#  4   isCoach   50 non-null     bool
#  5   teamId    38 non-null     float64
#  6   teamName  50 non-null     object
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
df1 = df.drop(columns = ['type'])
df1
# Out:
#          id   score                   name  isCoach    teamId  \
# 0    701154  301297          Kylian Mbappé    False    8633.0
# 1    292462  301159          Mohamed Salah    False    8650.0
# 2     30981  301149           Lionel Messi    False  960720.0
# 3    923312  301098           Bryan Mbeumo    False   10260.0
# 4    831489  301096    Alexis Mac Allister    False    8650.0
# 5   1158945  301094            Nuno Mendes    False    9847.0
# 6   1029063  301093          Michael Olise    False    9823.0
# 7   1156141  301093          Jamal Musiala    False    9823.0
# 8    534670  301092        Martin Ødegaard    False    9825.0
# 9   1031325  301092       Martín Zubimendi    False    9825.0
# 10  1137668  301091         Moisés Caicedo    False    8455.0
# 11   863098  301083          Matheus Cunha    False   10260.0
# 12   839204  301080          Omar Marmoush    False    8456.0
# 13   844425  301066             Marc Guéhi    False    8456.0
# ...

# %%
df2 = df1.iloc[0:38]

# %%
df2.to_csv("C:/Users/yaagh aiyappa/OneDrive/ドキュメント/csv_files/FootBallers.csv")
print('Done')
# Out:
# Done
